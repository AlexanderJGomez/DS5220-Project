# %%
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import csv
import nltk
import itertools
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr, spearmanr
from decimal import *
file_location = "../../data/DUC_Summary_Redundancy_Analysis/scores.csv"

# %%
df = pd.read_csv()

# %%
df
# Out:
#       topic selector assessor  system  qqn  score  \
# 0     D0601        A        A      10    2      4
# 1     D0601        A        A      11    2      4
# 2     D0601        A        A      12    2      4
# 3     D0601        A        A      13    2      4
# 4     D0601        A        A      14    2      4
# 5     D0601        A        A      15    2      4
# 6     D0601        A        A      16    2      4
# 7     D0601        A        A      17    2      4
# 8     D0601        A        A      18    2      4
# 9     D0601        A        A      19    2      4
# 10    D0601        A        A      20    2      4
# 11    D0601        A        A      21    2      4
# 12    D0601        A        A      22    2      4
# 13    D0601        A        A      23    2      4
# 14    D0601        A        A      24    2      4
# 15    D0601        A        A      25    2      4
# 16    D0601        A        A      26    2      4
# 17    D0601        A        A      27    2      4
# 18    D0601        A        A      28    2      4
# 19    D0601        A        A      29    2      4
# 20    D0601        A        A       2    2      4
# 21    D0601        A        A      30    2      3
# 22    D0601        A        A      31    2      4
# 23    D0601        A        A      32    2      4
# 24    D0601        A        A      33    2      4
# 25    D0601        A        A      34    2      4
# 26    D0601        A        A      35    2      4
# 27    D0601        A        A       3    2      4
# 28    D0601        A        A       4    2      4
# 29    D0601        A        A       5    2      4
# ...     ...      ...      ...     ...  ...    ...
# 1670  D0650        E        E      14    2      4
# 1671  D0650        E        E      15    2      4
# 1672  D0650        E        E      16    2      4
# 1673  D0650        E        E      17    2      4
# 1674  D0650        E        E      18    2      5
# 1675  D0650        E        E      19    2      4
# 1676  D0650        E        E      20    2      4
# 1677  D0650        E        E      21    2      5
# 1678  D0650        E        E      22    2      4
# 1679  D0650        E        E      23    2      3
# 1680  D0650        E        E      24    2      3
# 1681  D0650        E        E      25    2      3
# 1682  D0650        E        E      26    2      5
# 1683  D0650        E        E      27    2      4
# 1684  D0650        E        E      28    2      3
# 1685  D0650        E        E      29    2      4
# 1686  D0650        E        E       2    2      5
# 1687  D0650        E        E      30    2      5
# 1688  D0650        E        E      31    2      2
# 1689  D0650        E        E      32    2      4
# 1690  D0650        E        E      33    2      4
# 1691  D0650        E        E      34    2      4
# 1692  D0650        E        E      35    2      5
# 1693  D0650        E        E       3    2      5
# 1694  D0650        E        E       4    2      3
# 1695  D0650        E        E       5    2      4
# 1696  D0650        E        E       6    2      4
# 1697  D0650        E        E       7    2      5
# 1698  D0650        E        E       8    2      4
# 1699  D0650        E        E       9    2      4
#
#                                                 summary
# 0     Many reservation residents are frustrated.\nNa...
# 1     During 24-hour no-frills casino economic mirac...
# 2     The lack of such approval violates a federal l...
# 3     A century after Indian wars roiled the West, a...
# 4     Housing Secretary Andrew Cuomo, who visited th...
# 5     As crime rates fall nationwide, they are risin...
# 6     ''When we hire now, we want to hire people who...
# 7     As Indian communities across the nation strugg...
# 8     For their part, supporters of the measure have...
# 9     Juvenile crime is one strand in the web of soc...
# 10    Such success stories belong mostly to tribes w...
# 11    With economic opportunities on reservations la...
# 12    As Indian communities across the nation strugg...
# 13    Poverty among the Sioux on the Pine Ridge Indi...
# 14    Soldierwolf's family represents the problems t...
# 15    `` People are taking whatever they want out of...
# 16    Another factor is abuse passed down from gener...
# 17    David Rocchio, deputy legal counsel to Vermont...
# 18    It's the first step in a welfare reform progra...
# 19    Many in Shiprock hope Clinton's presence will ...
# 20    Among the spending Clinton will seek: $300 mil...
# 21    Concerning conditions, with economic opportuni...
# 22    Poverty among the Sioux on the Pine Ridge Indi...
# 23    Participation in the Agriculture Department's ...
# 24    Federal programs distributed to American India...
# 25    WASHINGTON (AP) -- American Indian reservation...
# 26    The Yakama Nation, which already bans liquor s...
# 27    Part of the problem in Navajo country and othe...
# 28    With the desperately needed jobs and money tha...
# 29    Participation in the Agriculture Department's ...
# ...                                                 ...
# 1670  The Carter Center said Friday that Peru does n...
# 1671  It worked out nicely to confer the medals on t...
# 1672  Coca-Cola, which has strong economic and polit...
# 1673  The idea for the Coca-Cola/Carter Center/Emory...
# 1674  The Central Elections Board said Wednesday it ...
# 1675  Carter did not specifically mention Chavez, or...
# 1676  Spokeswoman Deanna Congileo said the delegatio...
# 1677  He remains a vigorous man, rising every day at...
# 1678  Haas said that the Coca-Cola Co. does not have...
# 1679  Founded in 1982 by former U.S. president Jimmy...
# 1680  The mission observers belong to the "Carter Ce...
# 1681  LIMA, May 9 ( Xinhua ) Former US President Jim...
# 1682  That national assembly of 700 people will choo...
# 1683  But much of the former president's work now ap...
# 1684  The mission observers belong to the Carter Cen...
# 1685  The Carter Center said that Peru does not meet...
# 1686  President Alberto Fujimori has promised to com...
# 1687  The man and the woman from Plains deserve to b...
# 1688  To many minds, Jimmy Carter is the best ex-pre...
# 1689  The Carter Center Council has observed 14 elec...
# 1690  Spokeswoman Deanna Congileo said the delegatio...
# 1691  MEXICO CITY _ Former U.S. President Jimmy Cart...
# 1692  The Carter Center, founded by former President...
# 1693  That may underestimate John Quincy Adams, who ...
# 1694  Founded in 1982 by former U.S. president Jimmy...
# 1695  Former U.S. President Jimmy Carter will be in ...
# 1696  Now Carter seems downright amiable.\nCarter De...
# 1697  The government has promised to provide free br...
# 1698  It worked out nicely to confer the medals on t...
# 1699  President Jimmy Carter will head a group of in...
#
# [1700 rows x 7 columns]

# %%
BATCH_SIZE = 200
embed_batches = list(range(0, len(sentences), BATCH_SIZE))
use_sentence_embeddings = []

with tf.Graph().as_default():
    embed = hub.Module("https://tfhub.dev/google/universal-sentence-encoder-large/3")
    tf.logging.set_verbosity(tf.logging.ERROR)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        sess.run(tf.tables_initializer())
        for batch_index in embed_batches:
            print(batch_index)
            embeddings = embed(sentences[batch_index:batch_index+BATCH_SIZE])
            use_sentence_embeddings.extend(sess.run(embeddings))
